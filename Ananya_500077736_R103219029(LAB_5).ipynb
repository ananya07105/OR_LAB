# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya07105/OR_LAB/blob/main/Ananya_500077736_R103219029(LAB_5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Installing Library**

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.19.5)

# %% [markdown]
# **Loading Library**

# %%
from scipy import *

# %% [markdown]
# **PROBLEM-1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from scipy.optimize import linprog
import time
c = [-3,-2,-3]
A = [[2,1,1],[1,3,1],[3,4,2]]
b = [2,6,8]
x1_bnds = (0, None)
x2_bnds = (0, None)
x3_bnds = (0, None)
begin = time.time()
res = linprog(c, A_eq=A, b_eq=b, bounds=(x1_bnds, x2_bnds, x3_bnds), method='simplex', options={"disp":True})
print("Time taken: %s seconds"%(time.time()-begin))
print(res)
# Out:
# Optimization terminated successfully.
#          Current function value: -4.000000
#          Iterations: 3
# Time taken: 0.058656930923461914 seconds
#      con: array([0., 0., 0.])
#      fun: -4.0
#  message: 'Optimization terminated successfully.'
#      nit: 3
#    slack: array([], dtype=float64)
#   status: 0
#  success: True
#        x: array([0., 2., 0.])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# **PROBLEM-2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
c = [3,-4,3]
A = [[5,6,2],[1,-3,-5],[2,5,-4]]
b = [5,-8,4]
x1_bnds = (0, None)
x2_bnds = (0, None)
x3_bnds = (0, None)
begin = time.time()
res2 = linprog(c, A, b, bounds=(x1_bnds, x2_bnds, x3_bnds), method='simplex', options={"disp":True})
print("Time taken: %s seconds"%(time.time()-begin))
print(res2)
# Out:
# Optimization terminated successfully.
#          Current function value: 2.625000
#          Iterations: 3
# Time taken: 0.015067338943481445 seconds
#      con: array([], dtype=float64)
#      fun: 2.624999999999999
#  message: 'Optimization terminated successfully.'
#      nit: 3
#    slack: array([ 0.0000000e+00, -8.8817842e-16,  7.6250000e+00])
#   status: 0
#  success: True
#        x: array([0.   , 0.375, 1.375])

# %% [markdown]
# **PROBLEM-3**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
c = [-2,-4,-4,3]
A = [[1,1,1,0],[1,4,0,1],[3,4,2,0]]
b = [4,8,8]
x1_bnds = (0, None)
x2_bnds = (0, None)
x3_bnds = (0, None)
x4_bnds = (0, None)
begin=time.time()
res3 = linprog(c, A_eq=A, b_eq=b, bounds=(x1_bnds, x2_bnds, x3_bnds, x4_bnds), method='simplex', options={"disp":True})
print("Time taken: %s seconds"%(time.time()-begin))
print(res3)
# Out:
# Optimization terminated successfully.
#          Current function value: 8.000000
#          Iterations: 3
# Time taken: 0.0067255496978759766 seconds
#      con: array([0., 0., 0.])
#      fun: 8.0
#  message: 'Optimization terminated successfully.'
#      nit: 3
#    slack: array([], dtype=float64)
#   status: 0
#  success: True
#        x: array([0., 0., 4., 8.])
